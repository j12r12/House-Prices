# %%
import pandas as pd
import numpy as np

# %%
bob = [1,2,3]

# %%
print(bob)
# Out:
# [1, 2, 3]

# %%
frank = [2,4,6]

# %%
print(frank)
# Out:
# [2, 4, 6]

# %%
comb = [np.log10(i+j) for i, j in zip(bob, frank)]
print(comb)
# Out:
# [0.47712125471966244, 0.7781512503836436, 0.9542425094393249]
